# %%
import os
import shopify
from dotenv import load_dotenv
from pprint import pprint
# Load environment variables from .env file
load_dotenv()

# Retrieve Shopify credentials from environment variables
shop_url = os.getenv('SHOPIFY_SHOP_URL')
api_password = os.getenv('SHOPIFY_API_PASSWORD')
api_version = os.getenv('SHOPIFY_API_VERSION', '2021-07')

# Authenticate with the Shopify store
session = shopify.Session(shop_url=shop_url,
                          version=api_version,
                          token=api_password)

shopify.ShopifyResource.activate_session(session)

# %%
# Retrieve orders
orders = shopify.Order.find()

# %%
for order in orders: 
    #pprint(order.__dict__)
    pprint(order.customer.__dict__)
# Out:
# {'_initialized': True,
#  '_prefix_options': {},
#  'attributes': {'accepts_marketing': False,
#                 'accepts_marketing_updated_at': '2023-11-17T18:43:16-05:00',
#                 'admin_graphql_api_id': 'gid://shopify/Customer/6345157312583',
#                 'created_at': '2023-11-17T18:41:24-05:00',
#                 'currency': 'MXN',
#                 'default_address': default_address(7931551907911),
#                 'email': None,
#                 'email_marketing_consent': None,
#                 'first_name': 'Marco',
#                 'id': 6345157312583,
#                 'last_name': 'Burgos',
#                 'marketing_opt_in_level': None,
#                 'multipass_identifier': None,
#                 'note': '',
#                 'phone': None,
#                 'sms_marketing_consent': None,
#                 'state': 'disabled',
#                 'tags': '',
#                 'tax_exempt': False,
#                 'tax_exemptions': [],
#                 'updated_at': '2023-11-17T18:43:16-05:00',
#                 'verified_email': True},
#  'errors': <pyactiveresource.activeresource.Errors object at 0x000001C76E7133A0>,
#  'klass': <class 'shopify.resources.customer.Customer'>}
# {'_initialized': True,
#  '_prefix_options': {},
#  'attributes': {'accepts_marketing': False,
#                 'accepts_marketing_updated_at': '2023-11-17T18:43:16-05:00',
#                 'admin_graphql_api_id': 'gid://shopify/Customer/6345157312583',
#                 'created_at': '2023-11-17T18:41:24-05:00',
#                 'currency': 'MXN',
#                 'default_address': default_address(7931551907911),
#                 'email': None,
#                 'email_marketing_consent': None,
#                 'first_name': 'Marco',
#                 'id': 6345157312583,
#                 'last_name': 'Burgos',
#                 'marketing_opt_in_level': None,
#                 'multipass_identifier': None,
#                 'note': '',
#                 'phone': None,
#                 'sms_marketing_consent': None,
#                 'state': 'disabled',
#                 'tags': '',
#                 'tax_exempt': False,
#                 'tax_exemptions': [],
#                 'updated_at': '2023-11-17T18:43:16-05:00',
#                 'verified_email': True},
#  'errors': <pyactiveresource.activeresource.Errors object at 0x000001C76E69FB80>,
#  'klass': <class 'shopify.resources.customer.Customer'>}

# %%
# Iterate through orders and retrieve associated items
for order in orders:
    print(f"Order ID: {order.id}")
    print(f"Created at: {order.created_at}")
    print("Line Items:")

    customer = order.customer
    if customer:
        print("Customer Information:")
        print(f"  - Customer ID: {customer.id}")
        print(f"  - Name: {customer.first_name} {customer.last_name}")
        print(f"  - Email: {customer.email}")
        
        # Retrieve customer address
        address = customer.default_address
        if address:
            print("  - Address:")
            print(f"    {address.address1}")
            print(f"    {address.city}, {address.province_code} {address.zip}")
            print(f"    {address.country}")
            print("------------------------")

    print("Line Items:")
    
    # Retrieve line items for each order
    for line_item in order.line_items:
        print(f"  - Product ID: {line_item.product_id}")
        print(f"    Title: {line_item.title}")
        print(f"    Quantity: {line_item.quantity}")
        print(f"    Price: {line_item.price}")
        print("------------------------")

    print("\n")
# Out:
# Order ID: 5167242870855
# Created at: 2023-11-17T18:43:16-05:00
# Line Items:
# Customer Information:
#   - Customer ID: 6345157312583
#   - Name: Marco Burgos
#   - Email: None
#   - Address:
#     Av. Ignacio L Vallarta 5145
#     Zapopan, JAL 45040
#     Mexico
# ------------------------
# Line Items:
#   - Product ID: 6865551949895
#     Title: Chaqueta
#     Quantity: 10
#     Price: 1500.00
# ------------------------
#
#
# Order ID: 5167229304903
# Created at: 2023-11-17T18:34:41-05:00
# Line Items:
# Customer Information:
#   - Customer ID: 6345157312583
#   - Name: Marco Burgos
#   - Email: None
#   - Address:
#     Av. Ignacio L Vallarta 5145
#     Zapopan, JAL 45040
#     Mexico
# ------------------------
# Line Items:
#   - Product ID: 6865551949895
#     Title: Chaqueta
#     Quantity: 1
#     Price: 1500.00
# ------------------------
#   - Product ID: 6865974329415
#     Title: Red Snowboard
#     Quantity: 2
#     Price: 50.88
# ------------------------
